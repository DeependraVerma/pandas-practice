# %%
import pandas as pd
import numpy as np

# %%
import requests

url = "https://ipl-api1.p.rapidapi.com/match"

querystring = {"winner":"Kolkata Knight Riders"}

headers = {
	"X-RapidAPI-Key": "2ea5e31b2fmshb47858ea24201c3p192f94jsn8e4b27f31d31",
	"X-RapidAPI-Host": "ipl-api1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# [{'id': 335982, 'city': 'Bangalore', 'date': '2008-04-18', 'player_of_match': 'BB McCullum', 'venue': 'M Chinnaswamy Stadium', 'neutral_venue': 0, 'team1': 'Royal Challengers Bangalore', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Royal Challengers Bangalore', 'toss_decision': 'field', 'winner': 'Kolkata Knight Riders', 'result': 'runs', 'result_margin': 140.0, 'eliminator': 'N', 'method': None, 'umpire1': 'Asad Rauf', 'umpire2': 'RE Koertzen'}, {'id': 335986, 'city': 'Kolkata', 'date': '2008-04-20', 'player_of_match': 'DJ Hussey', 'venue': 'Eden Gardens', 'neutral_venue': 0, 'team1': 'Kolkata Knight Riders', 'team2': 'Deccan Chargers', 'toss_winner': 'Deccan Chargers', 'toss_decision': 'bat', 'winner': 'Kolkata Knight Riders', 'result': 'wickets', 'result_margin': 5.0, 'eliminator': 'N', 'method': None, 'umpire1': 'BF Bowden', 'umpire2': 'K Hariharan'}, {'id': 336010, 'city': 'Kolkata', 'date': '2008-05-08', 'player_of_match': 'SC Ganguly', 'venue': 'Eden Gardens', 'neutral_ve
# ...

# %%
pd.DataFrame(response.json())
# Out:
#          id       city        date player_of_match  \
# 0    335982  Bangalore  2008-04-18     BB McCullum
# 1    335986    Kolkata  2008-04-20       DJ Hussey
# 2    336010    Kolkata  2008-05-08      SC Ganguly
# 3    336014  Hyderabad  2008-05-11      SC Ganguly
# 4    336017    Kolkata  2008-05-13   Shoaib Akhtar
# ..      ...        ...         ...             ...
# 94  1216504      Dubai  2020-09-30     Shivam Mavi
# 95  1216512  Abu Dhabi  2020-10-18     LH Ferguson
# 96  1216523  Abu Dhabi  2020-10-10      KD Karthik
# 97  1216530      Dubai  2020-11-01      PJ Cummins
# 98  1216545  Abu Dhabi  2020-09-26    Shubman Gill
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1                                Eden Gardens              0
# 2                                Eden Gardens              0
# 3   Rajiv Gandhi International Stadium, Uppal              0
# ...

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/matches/v1/recent"

headers = {
	"X-RapidAPI-Key": "2ea5e31b2fmshb47858ea24201c3p192f94jsn8e4b27f31d31",
	"X-RapidAPI-Host": "cricbuzz-cricket.p.rapidapi.com"
}

response1 = requests.get(url, headers=headers)

print(response1.json()["typeMatches"])
# Out:
# [{'matchType': 'International', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 4786, 'seriesName': 'Ireland tour of England Only Test, 2023', 'matches': [{'matchInfo': {'matchId': 53408, 'seriesId': 4786, 'seriesName': 'Ireland tour of England Only Test, 2023', 'matchDesc': 'Only Test', 'matchFormat': 'TEST', 'startDate': '1685613600000', 'endDate': '1685898000000', 'state': 'Complete', 'status': 'England won by 10 wkts', 'team1': {'teamId': 27, 'teamName': 'Ireland', 'teamSName': 'IRE', 'imageId': 172141}, 'team2': {'teamId': 9, 'teamName': 'England', 'teamSName': 'ENG', 'imageId': 172123}, 'venueInfo': {'id': 19, 'ground': "Lord's", 'city': 'London', 'timezone': '+01:00', 'latitude': '51.529488', 'longitude': '-0.172926'}, 'currBatTeamId': 9, 'seriesStartDt': '1685059200000', 'seriesEndDt': '1686009600000', 'isTimeAnnounced': True, 'stateTitle': 'Complete', 'isFantasyEnabled': True}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 172, 'wickets': 10, 'overs': 5
# ...

# %%
pd.DataFrame(response1.json()["typeMatches"])
# Out:
#        matchType                                      seriesMatches
# 0  International  [{'seriesAdWrapper': {'seriesId': 4786, 'serie...
# 1         League  [{'seriesAdWrapper': {'seriesId': 5945, 'serie...
# 2       Domestic  [{'seriesAdWrapper': {'seriesId': 5127, 'serie...
# 3          Women  [{'seriesAdWrapper': {'seriesId': 6318, 'serie...

# %%
import requests

url = "https://cricket-live-data.p.rapidapi.com/match/2432999"

headers = {
	"X-RapidAPI-Key": "2ea5e31b2fmshb47858ea24201c3p192f94jsn8e4b27f31d31",
	"X-RapidAPI-Host": "cricket-live-data.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json()["results"])
# Out:
# {'fixture': {'id': 2432999, 'series_id': 608, 'match_title': 'Delhi Capitals v Kings XI Punjab at Dubai International Cricket Stadium (night), T20.', 'venue': 'Dubai International Cricket Stadium (night)', 'start_date': '2020-09-20T14:00:00+00:00', 'end_date': '2020-09-20T14:00:00+00:00', 'dates': [{'date': '2020-09-20T14:00:00+00:00', 'match_subtitle': '2nd Match'}], 'home': {'id': 120252, 'name': 'Delhi Capitals', 'code': ''}, 'away': {'id': 101748, 'name': 'Kings XI Punjab', 'code': 'KXI'}, 'series': {'series_id': 608, 'series_name': 'Indian Premier League', 'status': 'Winner Mumbai Indians', 'season': '2020/21', 'updated_at': '2021-10-12T23:00:05.000000Z'}}, 'live_details': {'match_summary': {'in_play': 'No', 'result': 'Yes', 'status': 'Match tied (Delhi Capitals won the one-over eliminator)', 'toss': 'Kings XI Punjab, elected to field first', 'home_scores': '157/8', 'away_scores': '157/8 (19.6/20 ov, target 158)'}, 'officials': {'umpire_1': 'Anil Chaudhary', 'umpire_2': 'Nitin M
# ...

# %%
pd.DataFrame(response.json()["results"])
# Out:
#                                                          fixture  \
# id                                                       2432999
# series_id                                                    608
# match_title    Delhi Capitals v Kings XI Punjab at Dubai Inte...
# venue                Dubai International Cricket Stadium (night)
# start_date                             2020-09-20T14:00:00+00:00
# end_date                               2020-09-20T14:00:00+00:00
# dates          [{'date': '2020-09-20T14:00:00+00:00', 'match_...
# home           {'id': 120252, 'name': 'Delhi Capitals', 'code...
# away           {'id': 101748, 'name': 'Kings XI Punjab', 'cod...
# series         {'series_id': 608, 'series_name': 'Indian Prem...
# match_summary                                                NaN
# officials                                                    NaN
# scorecard                                                    NaN
# ...

# %%
import requests

url = "https://api.themoviedb.org/3/configuration/jobs"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJkNWVhZGQ3ZDAyZTdkYTI2MjgyYmQ1YTg2YmQ0ZWUyZSIsInN1YiI6IjY0N2I3N2RkMTc0OTczMDEzNTAxNjUzNyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.NLGudZ9cekx5FV2uXSbkEgjVBhHnP1OFBq8Q5J30kbY"
}

response = requests.get(url, headers=headers)

print(response.json()[1])
# Out:
# {'department': 'Lighting', 'jobs': ['Directing Lighting Artist', 'Best Boy Electric', 'Rigging Gaffer', 'Best Boy Electrician', 'Lighting Coordinator', 'Lighting Director', 'Underwater Gaffer', 'Lighting Technician', 'Gaffer', 'Lighting Manager', 'Master Lighting Artist', 'Other', 'Rigging Supervisor', 'Lighting Supervisor', 'Lighting Production Assistant', 'Rigging Grip', 'Chief Lighting Technician', 'Lighting Artist', 'Electrician', 'O.B. Lighting', 'Additional Gaffer', 'Key Rigging Grip', 'Lighting Design', 'Assistant Electrician', 'Assistant Chief Lighting Technician', 'Best Boy Lighting Technician', 'Daily Electrics', 'Genetator Operator', 'Lighting Programmer', 'Standby Rigger', 'Additional Lighting Technician', 'Assistant Gaffer']}

# %%
pd.DataFrame(response.json()[1])
# Out:
#    department                                 jobs
# 0    Lighting            Directing Lighting Artist
# 1    Lighting                    Best Boy Electric
# 2    Lighting                       Rigging Gaffer
# 3    Lighting                 Best Boy Electrician
# 4    Lighting                 Lighting Coordinator
# 5    Lighting                    Lighting Director
# 6    Lighting                    Underwater Gaffer
# 7    Lighting                  Lighting Technician
# 8    Lighting                               Gaffer
# 9    Lighting                     Lighting Manager
# 10   Lighting               Master Lighting Artist
# 11   Lighting                                Other
# 12   Lighting                   Rigging Supervisor
# 13   Lighting                  Lighting Supervisor
# 14   Lighting        Lighting Production Assistant
# 15   Lighting                         Rigging Grip
# 16   Lighting            Chief Lighting Technician
# ...
