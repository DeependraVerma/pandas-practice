# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("aug_train.csv")

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %%
df = pd.read_csv('movie_titles_metadata.tsv.csv',sep='\t',names=['sno','name','release_year','rating','votes','genres'])

# %%
df
# Out:
#       sno                        name release_year  rating     votes  \
# 0      m0  10 things i hate about you         1999     6.9   62847.0
# 1      m1  1492: conquest of paradise         1992     6.2   10421.0
# 2      m2                  15 minutes         2001     6.1   25854.0
# 3      m3       2001: a space odyssey         1968     8.4  163227.0
# 4      m4                     48 hrs.         1982     6.9   22289.0
# ..    ...                         ...          ...     ...       ...
# 612  m612                    watchmen         2009     7.8  135229.0
# 613  m613                         xxx         2002     5.6   53505.0
# 614  m614                       x-men         2000     7.4  122149.0
# 615  m615          young frankenstein         1974     8.0   57618.0
# 616  m616                   zulu dawn         1979     6.4    1911.0
#
#                                                 genres
# 0                                 ['comedy' 'romance']
# ...

# %%
pd.read_csv("aug_train.csv",index_col=["enrollee_id"])
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...

# %%
df2 = pd.read_csv("test (1).csv")

# %%
df2
# Out:
#    Unnamed: 0   Unnamed: 1 Unnamed: 2              Unnamed: 3 Unnamed: 4  \
# 0           0  enrollee_id       city  city_development_index     gender
# 1           1        29725    city_40                   0.776       Male
# 2           2        11561    city_21                   0.624        NaN
# 3           3        33241   city_115                   0.789        NaN
# 4           4          666   city_162                   0.767       Male
#
#                 Unnamed: 5           Unnamed: 6       Unnamed: 7  \
# 0      relevent_experience  enrolled_university  education_level
# 1   No relevent experience        no_enrollment         Graduate
# 2   No relevent experience     Full time course         Graduate
# 3   No relevent experience                  NaN         Graduate
# 4  Has relevent experience        no_enrollment          Masters
#
#          Unnamed: 8  Unnamed: 9   Unnamed: 10     Unnamed: 11   Unnamed: 12  \
# ...

# %%
df2 = pd.read_csv("test (1).csv",header=1)

# %%
df2
# Out:
#    0  enrollee_id      city  city_development_index gender  \
# 0  1        29725   city_40                   0.776   Male
# 1  2        11561   city_21                   0.624    NaN
# 2  3        33241  city_115                   0.789    NaN
# 3  4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0   No relevent experience       no_enrollment        Graduate
# 1   No relevent experience    Full time course        Graduate
# 2   No relevent experience                 NaN        Graduate
# 3  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         15        50-99         Pvt Ltd           >4
# 1             STEM          5          NaN             NaN        never
# 2  Business Degree         <1          NaN         Pvt Ltd        never
# ...

# %%
df3 = pd.read_csv("aug_train.csv",usecols= ["city","gender","experience"])

# %%
df3
# Out:
#            city gender experience
# 0      city_103   Male        >20
# 1       city_40   Male         15
# 2       city_21    NaN          5
# 3      city_115    NaN         <1
# 4      city_162   Male        >20
# ...         ...    ...        ...
# 19153  city_173   Male         14
# 19154  city_103   Male         14
# 19155  city_103   Male        >20
# 19156   city_65   Male         <1
# 19157   city_67    NaN          2
#
# [19158 rows x 3 columns]

# %%
df4 = pd.read_csv("aug_train.csv",usecols=["enrollee_id"],squeeze=True)

# %%
df4
# Out:
# 0         8949
# 1        29725
# 2        11561
# 3        33241
# 4          666
#          ...
# 19153     7386
# 19154    31398
# 19155    24576
# 19156     5756
# 19157    23834
# Name: enrollee_id, Length: 19158, dtype: int64

# %%
df5 = pd.read_csv("aug_train.csv",nrows=100)

# %%
df5
# Out:
#     enrollee_id      city  city_development_index gender  \
# 0          8949  city_103                   0.920   Male
# 1         29725   city_40                   0.776   Male
# 2         11561   city_21                   0.624    NaN
# 3         33241  city_115                   0.789    NaN
# 4           666  city_162                   0.767   Male
# ..          ...       ...                     ...    ...
# 95        12081   city_65                   0.802   Male
# 96         7364  city_160                   0.920    NaN
# 97        11184   city_74                   0.579    NaN
# 98         7016   city_65                   0.802   Male
# 99         8695   city_11                   0.550   Male
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# ...

# %%
df6 = pd.read_csv("aug_train.csv",skiprows=[0])

# %%
df6
# Out:
#         8949  city_103   0.92  Male  Has relevent experience  \
# 0      29725   city_40  0.776  Male   No relevent experience
# 1      11561   city_21  0.624   NaN   No relevent experience
# 2      33241  city_115  0.789   NaN   No relevent experience
# 3        666  city_162  0.767  Male  Has relevent experience
# 4      21651  city_176  0.764   NaN  Has relevent experience
# ...      ...       ...    ...   ...                      ...
# 19152   7386  city_173  0.878  Male   No relevent experience
# 19153  31398  city_103  0.920  Male  Has relevent experience
# 19154  24576  city_103  0.920  Male  Has relevent experience
# 19155   5756   city_65  0.802  Male  Has relevent experience
# 19156  23834   city_67  0.855   NaN   No relevent experience
#
#           no_enrollment        Graduate             STEM  >20 Unnamed: 9  \
# 0         no_enrollment        Graduate             STEM   15      50-99
# 1      Full time course        Graduate             STEM    5        NaN
# ...

# %%
df7 = pd.read_csv("zomato.csv",encoding="utf-8",sep= ",")

# %%
df7
# Out:
#                                           Restaurant ID  Restaurant Name  \
# 0     6317637,Le Petit Souffle,162,Makati City,"Thir...              NaN
# 1     6304287,Izakaya Kikufuji,162,Makati City,"Litt...              NaN
# 2     6300002,Heat - Edsa Shangri-La,162,Mandaluyong...              NaN
# 3     6318506,Ooma,162,Mandaluyong City,"Third Floor...              NaN
# 4     6314302,Sambo Kojin,162,Mandaluyong City,"Thir...              NaN
# ...                                                 ...              ...
# 9552  5915730,Naml۱ Gurme,208,��stanbul,"Kemanke�� K...              NaN
# 9553  5908749,Ceviz A��ac۱,208,��stanbul,"Ko��uyolu ...              NaN
# 9554  5915807,Huqqa,208,��stanbul,"Kuru�_e��me Mahal...              NaN
# 9555  5916112,A���k Kahve,208,��stanbul,"Kuru�_e��me...              NaN
# 9556  5927402,Walter's Coffee Roastery,208,��stanbul...              NaN
#
#       Country Code  City  Address  Locality  Locality Verbose  Longitude  \
# ...

# %%
df7 = pd.read_csv("zomato.csv",encoding="utf-8",sep= ",",error_bad_lines=False)

# %%
df7
# Out:
#                                           Restaurant ID  Restaurant Name  \
# 0     6317637,Le Petit Souffle,162,Makati City,"Thir...              NaN
# 1     6304287,Izakaya Kikufuji,162,Makati City,"Litt...              NaN
# 2     6300002,Heat - Edsa Shangri-La,162,Mandaluyong...              NaN
# 3     6318506,Ooma,162,Mandaluyong City,"Third Floor...              NaN
# 4     6314302,Sambo Kojin,162,Mandaluyong City,"Thir...              NaN
# ...                                                 ...              ...
# 9552  5915730,Naml۱ Gurme,208,��stanbul,"Kemanke�� K...              NaN
# 9553  5908749,Ceviz A��ac۱,208,��stanbul,"Ko��uyolu ...              NaN
# 9554  5915807,Huqqa,208,��stanbul,"Kuru�_e��me Mahal...              NaN
# 9555  5916112,A���k Kahve,208,��stanbul,"Kuru�_e��me...              NaN
# 9556  5927402,Walter's Coffee Roastery,208,��stanbul...              NaN
#
#       Country Code  City  Address  Locality  Locality Verbose  Longitude  \
# ...

# %%
df8 = pd.read_csv("aug_train.csv",dtype={"target":int})

# %%
df8
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df9 = pd.read_csv("IPL Matches 2008-2020.csv").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    object
#  1   city             611 non-null    object
#  2   date             624 non-null    object
#  3   player_of_match  620 non-null    object
#  4   venue            624 non-null    object
#  5   neutral_venue    624 non-null    float64
#  6   team1            624 non-null    object
#  7   team2            624 non-null    object
#  8   toss_winner      624 non-null    object
#  9   toss_decision    624 non-null    object
#  10  winner           620 non-null    object
#  11  result           620 non-null    object
#  12  result_margin    610 non-null    float64
#  13  eliminator       620 non-null    object
#  14  method           17 non-null     object
#  15  umpire1          624 non-null    object
# ...

# %%
df10 = pd.read_csv("IPL Matches 2008-2020.csv", parse_dates=["date"])

# %%
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    object
#  1   city             611 non-null    object
#  2   date             624 non-null    datetime64[ns]
#  3   player_of_match  620 non-null    object
#  4   venue            624 non-null    object
#  5   neutral_venue    624 non-null    float64
#  6   team1            624 non-null    object
#  7   team2            624 non-null    object
#  8   toss_winner      624 non-null    object
#  9   toss_decision    624 non-null    object
#  10  winner           620 non-null    object
#  11  result           620 non-null    object
#  12  result_margin    610 non-null    float64
#  13  eliminator       620 non-null    object
#  14  method           17 non-null     object
#  15  umpire1          624 non-null    object
# ...

# %%
df11 = pd.read_csv("IPL Matches 2008-2020.csv")

# %%
df11
# Out:
#                                                     id       city        date  \
# 0                                               335982  Bangalore  2008-04-18
# 1    335983,Chandigarh,2008-04-19,MEK Hussey,"Punja...        NaN         NaN
# 2                                               335984      Delhi  2008-04-19
# 3                                               335985     Mumbai  2008-04-20
# 4                                               335986    Kolkata  2008-04-20
# ..                                                 ...        ...         ...
# 811                                            1216547      Dubai  2020-09-28
# 812                                            1237177      Dubai  2020-11-05
# 813                                            1237178  Abu Dhabi  2020-11-06
# 814                                            1237180  Abu Dhabi  2020-11-08
# 815                                            1237181      Dubai  2020-11-10
#
# ...

# %%
def rename(name):
    if name == "Royal Challengers Bangalore":
        return "RCB"
    else:
        return name

# %%
rename("Royal Challengers Bangalore")
# Out:
# 'RCB'

# %%
df12 = pd.read_csv("IPL Matches 2008-2020.csv", converters={"team1":rename})

# %%
df12
# Out:
#                                                     id       city        date  \
# 0                                               335982  Bangalore  2008-04-18
# 1    335983,Chandigarh,2008-04-19,MEK Hussey,"Punja...        NaN         NaN
# 2                                               335984      Delhi  2008-04-19
# 3                                               335985     Mumbai  2008-04-20
# 4                                               335986    Kolkata  2008-04-20
# ..                                                 ...        ...         ...
# 811                                            1216547      Dubai  2020-09-28
# 812                                            1237177      Dubai  2020-11-05
# 813                                            1237178  Abu Dhabi  2020-11-06
# 814                                            1237180  Abu Dhabi  2020-11-08
# 815                                            1237181      Dubai  2020-11-10
#
# ...

# %%
df13 = pd.read_csv("aug_train.csv", na_values=["Male"])

# %%
df13
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920    NaN
# 1            29725   city_40                   0.776    NaN
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767    NaN
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878    NaN
# 19154        31398  city_103                   0.920    NaN
# 19155        24576  city_103                   0.920    NaN
# 19156         5756   city_65                   0.802    NaN
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df14 = pd.read_csv("aug_train.csv")

# %%
df14
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df15 = pd.read_csv("aug_train.csv",chunksize=5000)

# %%
for chunks in df15:
    print(chunks.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (5000, 14)
# (4158, 14)
